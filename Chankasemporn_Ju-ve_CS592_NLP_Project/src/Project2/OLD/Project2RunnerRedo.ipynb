# %% [markdown]
# #Assignment 2 – Knowledge Graph

# %% [markdown]
# Perform Named-Entity Recognition (NER) on the corpus documents
#
# Identify, and list, the entities and their labels that are recognized by spaCy’s default medium-sized model (‘en_core_web_md’);

# %%
import src.Project2.NER_Extraction.data_extractor as DataExtraction
import src.Project2.OLD.Data_Extraction.data_collection as DataCollection

nlp = DataExtraction.initialize_nlp()

root, file_path = DataExtraction.load_corpus(
    "Shakespeare_Much_Ado_About_Nothing.txt", "train"
)

characters = DataCollection.collectCharacterInfo(root)
locations = DataCollection.collectLocationInfo(root.find(".//Body"))

print(characters)
print("\n")
print(locations)
# Out:
# [{'name': 'DON PEDRO', 'desc': 'Prince of Arragon'}, {'name': 'DON JOHN', 'desc': 'his bastard Brother'}, {'name': 'CLAUDIO', 'desc': 'a young Lord of Florence'}, {'name': 'BENEDICK', 'desc': 'a young Lord of Padua'}, {'name': 'LEONATO', 'desc': 'Governor of Messina'}, {'name': 'ANTONIO', 'desc': 'his Brother'}, {'name': 'BALTHASAR', 'desc': 'Servant to Don Pedro'}, {'name': 'BORACHIO', 'desc': 'follower of Don John'}, {'name': 'CONRADE', 'desc': 'follower of Don John'}, {'name': 'DOGBERRY', 'desc': 'a Constable'}, {'name': 'VERGES', 'desc': 'a Headborough'}, {'name': 'FRIAR FRANCIS.', 'desc': ''}, {'name': 'A Sexton.', 'desc': ''}, {'name': 'A Boy.', 'desc': ''}, {'name': 'HERO', 'desc': 'Daughter to Leonato'}, {'name': 'BEATRICE', 'desc': 'Niece to Leonato'}, {'name': 'MARGARET', 'desc': 'Waiting gentlewoman attending on Hero'}, {'name': 'URSULA', 'desc': 'Waiting gentlewoman attending on Hero'}, {'name': 'Messengers', 'desc': 'Watch, Attendants, etc'}]
#
#
# ...
