# %%
# My first Jupyter notebook cell
print("Hello, Python World!")
print("This is running in a virtual environment")
# Let's do some basic math
x = 10
y = 20
result = x + y
print(f"The sum of {x} and {y} is {result}")
# Out:
# Hello, Python World!
# This is running in a virtual environment
# The sum of 10 and 20 is 30

# %%
# Working with lists and loops
fruits = ["apple", "banana", "cherry", "date"]
print("My favorite fruits:")
for i, fruit in enumerate(fruits, 1):
    print(f"{i}. {fruit}")
# Check Python version and virtual environment
import sys
print(f"\nPython version: {sys.version}")
print(f"Python executable: {sys.executable}")
# Out:
# My favorite fruits:
# 1. apple
# 2. banana
# 3. cherry
# 4. date
#
# Python version: 3.9.9 (tags/v3.9.9:ccb0e6a, Nov 15 2021, 18:08:50) [MSC v.1929 64 bit (AMD64)]
# Python executable: E:\DigiPenMasterCourse\Semester3_2025\mat598\mat598\PythonProject\.venv\Scripts\python.exe
